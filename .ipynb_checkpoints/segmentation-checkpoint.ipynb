# %%
#import os
#os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
#os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
import numpy as np
import scipy.io as scio    
import os,re
import imageio
from scipy import ndimage
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import *
from keras.layers import Input, merge, Conv2D, MaxPooling2D, UpSampling2D, Dropout, Cropping2D,Concatenate
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler,ReduceLROnPlateau,CSVLogger
from keras import backend as keras

# %%
images = np.load('total_images.npy')
gt_labels = np.load('gt_labels_binary.npy')

# %%
print(len(images))
print(len(gt_labels))
# Out:
# 175
# 250

# %%
train_indices = np.random.choice(174,164,replace=False)
print(len(train_indices))
# Out:
# 164

# %%
train_images = [images[i] for i in train_indices]
train_labels = [gt_labels[i] for i in train_indices]

# %%
print(len(train_images))
print(len(train_labels))
# Out:
# 164
# 164

# %%
test_indices = [i for i in range(175) if i not in train_indices]
print(len(test_indices))
# Out:
# 11

# %%
test_images = [images[i] for i in test_indices]
test_labels = [gt_labels[i] for i in test_indices]

# %%
print(len(test_images))
print(len(test_labels))
# Out:
# 11
# 11

# %%
plt.imshow(images[0])
plt.show()

# %%
plt.imshow(gt_labels[0])
plt.show()

# %%
print(gt_labels.shape)
# Out:
# (250, 128, 128)

# %%
image_dims = images[0].shape
print(image_dims)
# Out:
# (128, 128, 3)

# %%
train_mean = np.mean(train_images,axis = (0,1,2,3))
train_std = np.std(train_images,axis = (0,1,2,3))
train_images = (train_images - train_mean)/(train_std+1e-7)

# %%
test_mean = np.mean(test_images,axis=(0,1,2,3))
test_std = np.std(test_images,axis = (0,1,2,3))
test_images = (test_images-test_mean)/(test_std+1e-7)

# %%
train_labels = np.expand_dims(train_labels,axis=3)
test_labels = np.expand_dims(test_labels,axis=3)

# %%
print(train_labels.shape)
print(test_labels.shape)
# Out:
# (164, 128, 128, 1)
# (11, 128, 128, 1)

# %%
np.save('train_images.npy',train_images)
np.save('test_images.npy',test_images)
np.save('train_labels.npy',train_labels)
np.save('test_labels.npy',test_labels)

# %%
train_images = np.load('train_images.npy')
test_images = np.load('test_images.npy')
train_labels = np.load('train_labels.npy')
test_labels = np.load('test_labels.npy')

# %%
train_images[0].shape
# Out:
# (128, 128, 3)

# %%
plt.imshow(train_images[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
test_labels[0].shape
# Out:
# (128, 128, 1)

# %%
plt.imshow(test_labels[0].reshape((128,128)), cmap = "gray")

# %%
def get_unet_model(image_dims):
    inputs = Input((image_dims[0],image_dims[1],image_dims[2]))
    conv1 = Conv2D(16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
   

    up6 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
    merge6 = Concatenate(axis=3)([conv4,up6])
    conv6 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = Concatenate(axis=3)([conv3,up7])
    conv7 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = Concatenate(axis=3)([conv2,up8])
    conv8 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    up9 = Conv2D(16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = Concatenate(axis=3)([conv1,up9])
    conv9 = Conv2D(16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
  #  conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = Model(inputs = inputs, outputs = conv10)
    return model

# %%
model = get_unet_model((128,128,3))
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 16) 2320        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  147584      conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 256)    295168      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 256)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  295040      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 256)  0           conv2d_8[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 128)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   73792       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 128)  0           conv2d_6[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 64)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 32)   18464       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 64)   0           conv2d_4[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 32)   9248        conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 32) 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 16) 4624        up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 32) 0           conv2d_2[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 16) 2320        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 1)  17          conv2d_22[0][0]
# ==================================================================================================
# Total params: 2,158,705
# Trainable params: 2,158,705
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = Adam(lr = 1e-3), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
lr_reducer = ReduceLROnPlateau(factor=0.5, cooldown=0, patience=6, min_lr=0.5e-6)
csv_logger = CSVLogger('Unet_lr_e4_bs_10.csv')
model_checkpoint = ModelCheckpoint("Unet_lr_e4_bs_10.hdf5",monitor = 'val_loss',verbose = 1,save_best_only=True)

# %%
model.fit(train_images, train_labels, batch_size=4, epochs=25, verbose=1,validation_data=(test_images,test_labels), shuffle=True, callbacks=[lr_reducer,csv_logger,model_checkpoint])
# Out:
# Train on 164 samples, validate on 11 samples
# Epoch 1/25
# 164/164 [==============================] - 34s 207ms/step - loss: 0.3922 - accuracy: 0.8187 - val_loss: 0.5135 - val_accuracy: 0.7635
#
# Epoch 00001: val_loss did not improve from 0.50015
# Epoch 2/25
# 164/164 [==============================] - 33s 204ms/step - loss: 0.3862 - accuracy: 0.8214 - val_loss: 0.5195 - val_accuracy: 0.7746
#
# Epoch 00002: val_loss did not improve from 0.50015
# Epoch 3/25
# 164/164 [==============================] - 33s 202ms/step - loss: 0.3857 - accuracy: 0.8221 - val_loss: 0.5054 - val_accuracy: 0.7866
#
# Epoch 00003: val_loss did not improve from 0.50015
# Epoch 4/25
# 164/164 [==============================] - 34s 207ms/step - loss: 0.3825 - accuracy: 0.8238 - val_loss: 0.5050 - val_accuracy: 0.7819
#
# Epoch 00004: val_loss did not improve from 0.50015
# Epoch 5/25
# 164/164 [==============================] - 33s 203ms/step - loss: 0.3779 - accuracy: 0.8262 - val_loss: 0.4993 - val_accuracy: 0.7821
#
# Epoch 00005: val_loss improved from 0.50015 to 0.49925, saving model to Unet_lr_e4_bs_10.hdf5
# Epoch 6/25
# 164/164 [==============================] - 34s 205ms/step - loss: 0.3802 - accuracy: 0.8259 - val_loss: 0.5073 - val_accuracy: 0.7675
#
# Epoch 00006: val_loss did not improve from 0.49925
# Epoch 7/25
# 164/164 [==============================] - 33s 202ms/step - loss: 0.3796 - accuracy: 0.8260 - val_loss: 0.4990 - val_accuracy: 0.7827
#
# Epoch 00007: val_loss improved from 0.49925 to 0.49903, saving model to Unet_lr_e4_bs_10.hdf5
# Epoch 8/25
# 164/164 [==============================] - 34s 206ms/step - loss: 0.3758 - accuracy: 0.8276 - val_loss: 0.5708 - val_accuracy: 0.7501
#
# Epoch 00008: val_loss did not improve from 0.49903
# Epoch 9/25
# 164/164 [==============================] - 33s 203ms/step - loss: 0.3716 - accuracy: 0.8312 - val_loss: 0.5039 - val_accuracy: 0.7783
#
# Epoch 00009: val_loss did not improve from 0.49903
# Epoch 10/25
# 164/164 [==============================] - 33s 204ms/step - loss: 0.3628 - accuracy: 0.8382 - val_loss: 0.5167 - val_accuracy: 0.7803
#
# Epoch 00010: val_loss did not improve from 0.49903
# Epoch 11/25
# 164/164 [==============================] - 34s 206ms/step - loss: 0.3689 - accuracy: 0.8325 - val_loss: 0.6024 - val_accuracy: 0.7292
#
# Epoch 00011: val_loss did not improve from 0.49903
# Epoch 12/25
# 164/164 [==============================] - 33s 203ms/step - loss: 0.3811 - accuracy: 0.8251 - val_loss: 0.5482 - val_accuracy: 0.7569
#
# Epoch 00012: val_loss did not improve from 0.49903
# Epoch 13/25
# 164/164 [==============================] - 33s 203ms/step - loss: 0.3615 - accuracy: 0.8363 - val_loss: 0.5547 - val_accuracy: 0.7705
#
# Epoch 00013: val_loss did not improve from 0.49903
# Epoch 14/25
# 164/164 [==============================] - 33s 202ms/step - loss: 0.3450 - accuracy: 0.8443 - val_loss: 0.5678 - val_accuracy: 0.7597
#
# Epoch 00014: val_loss did not improve from 0.49903
# Epoch 15/25
# 164/164 [==============================] - 34s 205ms/step - loss: 0.3356 - accuracy: 0.8498 - val_loss: 0.5656 - val_accuracy: 0.7627
#
# Epoch 00015: val_loss did not improve from 0.49903
# Epoch 16/25
# 164/164 [==============================] - 33s 202ms/step - loss: 0.3315 - accuracy: 0.8523 - val_loss: 0.5526 - val_accuracy: 0.7705
#
# Epoch 00016: val_loss did not improve from 0.49903
# Epoch 17/25
# 164/164 [==============================] - 33s 203ms/step - loss: 0.3256 - accuracy: 0.8546 - val_loss: 0.5371 - val_accuracy: 0.7783
#
# Epoch 00017: val_loss did not improve from 0.49903
# Epoch 18/25
# 164/164 [==============================] - 34s 207ms/step - loss: 0.3180 - accuracy: 0.8579 - val_loss: 0.5724 - val_accuracy: 0.7733
#
# Epoch 00018: val_loss did not improve from 0.49903
# Epoch 19/25
# 164/164 [==============================] - 34s 210ms/step - loss: 0.3151 - accuracy: 0.8593 - val_loss: 0.5629 - val_accuracy: 0.7749
#
# Epoch 00019: val_loss did not improve from 0.49903
# Epoch 20/25
# 164/164 [==============================] - 35s 212ms/step - loss: 0.3042 - accuracy: 0.8660 - val_loss: 0.6114 - val_accuracy: 0.7644
#
# Epoch 00020: val_loss did not improve from 0.49903
# Epoch 21/25
# 164/164 [==============================] - 35s 215ms/step - loss: 0.2925 - accuracy: 0.8706 - val_loss: 0.6416 - val_accuracy: 0.7554
#
# Epoch 00021: val_loss did not improve from 0.49903
# Epoch 22/25
# 164/164 [==============================] - 35s 212ms/step - loss: 0.2874 - accuracy: 0.8724 - val_loss: 0.6576 - val_accuracy: 0.7540
#
# Epoch 00022: val_loss did not improve from 0.49903
# Epoch 23/25
# 164/164 [==============================] - 35s 211ms/step - loss: 0.2810 - accuracy: 0.8763 - val_loss: 0.6794 - val_accuracy: 0.7516
#
# Epoch 00023: val_loss did not improve from 0.49903
# Epoch 24/25
# 164/164 [==============================] - 34s 208ms/step - loss: 0.2737 - accuracy: 0.8800 - val_loss: 0.6867 - val_accuracy: 0.7595
#
# Epoch 00024: val_loss did not improve from 0.49903
# Epoch 25/25
# 164/164 [==============================] - 34s 206ms/step - loss: 0.2684 - accuracy: 0.8824 - val_loss: 0.7147 - val_accuracy: 0.7440
#
# Epoch 00025: val_loss did not improve from 0.49903

# %%
model.load_weights('Unet_lr_e4_bs_10.hdf5')

# %%
train_images.shape
# Out:
# (164, 128, 128, 3)

# %%
test_images = np.expand_dims(test_images,axis=1)

# %%
sample  = train_images[0]
sample = sample.reshape(1,128,128,3)

# %%
predictions = model.predict(test_images[5].reshape((1,128,128,3)))

# %%
predictions.shape
# Out:
# (1, 128, 128, 1)

# %%
predictions = predictions.reshape((128,128))

# %%
results = predictions > 0.5

# %%
results.shape
# Out:
# (128, 128)

# %%
plt.imshow(results, cmap = "gray")
